# %%
# %%file romberg.f90
#     SUBROUTINE polint(xx, yy, n, x, y, err, c, d)
#     ! Routine to find one interpolated value given a table of n values
#     implicit none
#
#     ! Inputs and outputs
#     integer, intent(in) :: n
#     real*8, dimension(n), intent(in) :: xx, yy
#     real*8, intent(in) :: x
#     real*8, intent(out) :: y, err
#     real*8, dimension(n), intent(out) :: c, d
#
#     ! Local variables
#     integer :: i, m, ns
#     real*8 :: den, dif, dift, ho, hp, w
#     ns = 1
#     dif = ABS(x - xx(1))
#
#     ! Find the nearest point
#     do i = 1, n
#         dift = ABS(x - xx(i))
#         if (dift < dif) then
#             ns = i
#             dif = dift
#         end if
#         c(i) = yy(i)
#         d(i) = yy(i)
#     end do
#
#     y = yy(ns)
#     ns = ns - 1
#
#     ! Calculate polynomial interpolation
#     do m = 1, n - 1
#         do i = 1, n - m
#             ho = xx(i) - x
#             hp = xx(i + m) - x
#             w = c(i + 1) - d(i)
#             den = ho - hp
#             if (den == 0.0d0) pause 'Failure in polint: denominator is zero'
#             den = w / den
#             d(i) = hp * den
#             c(i) = ho * den
#         end do
#         if (2 * ns < n - m) then
#             err = c(ns + 1)
#         else
#             err = d(ns)
#             ns = ns - 1
#         end if
#         y = y + err
#     end do
#
#     return
#     end subroutine polint
#
#
#     SUBROUTINE trapzd(func, a, b, sin, sout, n)
#     ! Routine to perform the trapezoidal rule for numerical integration
#     implicit none
#
#     ! Inputs and outputs
#     real*8, intent(in) :: a, b, sin
#     real*8, intent(out) :: sout
#     integer, intent(in) :: n
#     external :: func
#
#     ! Local variables
#     integer :: it, j
#     real*8 :: del, sum, tnm, x
#
#     if (n == 1) then
#         sout = 0.5d0 * (b - a) * (func(a) + func(b))
#     else
#         it = 2**(n - 2)
#         tnm = it
#         del = (b - a) / tnm
#         x = a + 0.5d0 * del
#         sum = 0.d0
#
#         do j = 1, it
#             sum = sum + func(x)
#             x = x + del
#         end do
#
#         sout = 0.5d0 * (sin + (b - a) * sum / tnm)
#     end if
#
#     return
#     end subroutine trapzd
#
#
#     SUBROUTINE qromb(func, a, b, ss, dss, numcalls, EPS, K, c, d)
#     ! Routine to perform Romberg integration
#     implicit none
#
#     ! Inputs and outputs
#     real*8, intent(out) :: ss, dss
#     integer, intent(out) :: numcalls
#     real*8, optional, intent(in) :: EPS
#     integer, optional, intent(in) :: K
#     real*8, dimension(K), intent(hide) :: c, d
#     real*8, intent(in) :: a, b
#
#     external :: func
#
#     ! Local variables
#     integer :: JMAX, JMAXP, KM, j
#     real*8 :: h(JMAXP), s(JMAXP), sold
#     real*8 :: y1, y2
#
#     ! Parameters
#     parameter (EPS = 1.e-6, JMAX = 20, JMAXP = JMAX + 1, K = 5, KM = K - 1)
#     h(1) = 1.d0
#     KM = K - 1
#     sold = 0.0d0
#
#     ! Romberg integration loop
#     do j = 1, JMAX
#         call trapzd(func, a, b, sold, s(j), j)
#         if (j >= K) then
#             call polint(h(j - KM), s(j - KM), K, 0.d0, ss, dss, c, d)
#             if (ABS(dss) <= EPS * ABS(ss)) then
#                 numcalls = 2**(j - 1) + 1
#                 return
#             end if
#         end if
#         sold = s(j)
#         h(j + 1) = 0.25d0 * h(j)
#     end do
#
#     ! No convergence
#     numcalls = -1
#     return
#     end subroutine qromb
# Out:
# Writing romberg.f90

# %%
import os ,sys

# %%
# !python -m numpy.f2py -c romberg.f90 -m romberg
# Out:
# running build
# running config_cc
# INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# INFO: build_src
# INFO: building extension "romberg" sources
# INFO: f2py options: []
# INFO: f2py:> C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9
# Reading fortran codes...
# 	Reading file 'romberg.f90' (format:free)
# Line #112 in romberg.f90:"    parameter (EPS = 1.e-6, JMAX = 20, JMAXP = JMAX + 1, K = 5, KM = K - 1) "
# 	param_eval: got "eval() arg 1 must be a string, bytes or code object" on 4
# Line #112 in romberg.f90:"    parameter (EPS = 1.e-6, JMAX = 20, JMAXP = JMAX + 1, K = 5, KM = K - 1) "
# 	param_eval: got "eval() arg 1 must be a string, bytes or code object" on 4
# Line #112 in romberg.f90:"    parameter (EPS = 1.e-6, JMAX = 20, JMAXP = JMAX + 1, K = 5, KM = K - 1) "
# 	param_eval: got "eval() arg 1 must be a string, bytes or code object" on 4
# Line #112 in romberg.f90:"    parameter (EPS = 1.e-6, JMAX = 20, JMAXP = JMAX + 1, K = 5, KM = K - 1) "
# 	param_eval: got "eval() arg 1 must be a string, bytes or code object" on 4
# Post-processing...
# 	Block: romberg
# 			Block: polint
# 			Block: trapzd
# 					Block: func
# 			Block: qromb
# In: :romberg:romberg.f90:qromb
# param_eval: got "eval() arg 1 must be a string, bytes or code object" on 4
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Building modules...
#     Constructing call-back function "cb_func_in_trapzd__user__routines"
#       def func(x): return sum
#     Building module "romberg"...
#     Generating possibly empty wrappers"
#     Maybe empty "romberg-f2pywrappers.f"
#         Constructing wrapper function "polint"...
#           y,err,c,d = polint(xx,yy,x,[n])
#     Generating possibly empty wrappers"
#     Maybe empty "romberg-f2pywrappers.f"
#         Constructing wrapper function "trapzd"...
#           sout = trapzd(func,a,b,sin,n,[func_extra_args])
#     Generating possibly empty wrappers"
#     Maybe empty "romberg-f2pywrappers.f"
#         Constructing wrapper function "qromb"...
#           ss,dss,numcalls = qromb(func,a,b,[eps,k,func_extra_args])
#     Wrote C/API module "romberg" to file "C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c"
# INFO:   adding 'C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\fortranobject.c' to sources.
# INFO:   adding 'C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9' to include_dirs.
# copying d:\Anaconda\lib\site-packages\numpy\f2py\src\fortranobject.c -> C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9
# copying d:\Anaconda\lib\site-packages\numpy\f2py\src\fortranobject.h -> C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9
# INFO:   adding 'C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\romberg-f2pywrappers.f' to sources.
# INFO: build_src: building npy-pkg config files
# running build_ext
# INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
# INFO: customize MSVCCompiler
# INFO: customize MSVCCompiler using build_ext
# INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
# INFO: customize GnuFCompiler
# WARN: Could not locate executable g77
# WARN: Could not locate executable f77
# INFO: customize IntelVisualFCompiler
# WARN: Could not locate executable ifort
# WARN: Could not locate executable ifl
# INFO: customize AbsoftFCompiler
# WARN: Could not locate executable f90
# INFO: customize CompaqVisualFCompiler
# WARN: Could not locate executable DF
# INFO: customize IntelItaniumVisualFCompiler
# WARN: Could not locate executable efl
# INFO: customize Gnu95FCompiler
# INFO: Found executable C:\msys64\ucrt64\bin\gfortran.exe
# INFO: customize Gnu95FCompiler
# INFO: customize Gnu95FCompiler using build_ext
# INFO: building 'romberg' extension
# INFO: compiling C sources
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local\Temp
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local\Temp\tmp8qnvu50b
# creating C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9
# INFO: C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.40.33807\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DNPY_DISABLE_OPTIMIZATION=1 -IC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9 -Id:\Anaconda\lib\site-packages\numpy\core\include -Id:\Anaconda\include -Id:\Anaconda\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.40.33807\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /TcC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c /FoC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.obj
# rombergmodule.c
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(341): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(538): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(653): warning C4244: '=': conversion from 'npy_intp' to 'int', possible loss of data
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(910): error C2065: 'func_t': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(910): error C2146: syntax error: missing ';' before identifier 'func_cb'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(910): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(910): error C2059: syntax error: '{'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(911): error C2065: 'func_t': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(911): error C2065: 'func_cb_ptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(911): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(911): warning C4047: '=': 'int' differs in levels of indirection from 'int *'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(911): error C2106: '=': left operand must be l-value
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(913): error C2065: 'func_typedef': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(913): error C2146: syntax error: missing ';' before identifier 'func_cptr'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(913): error C2065: 'func_cptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(943): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(943): error C2224: left of '.capi' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(992): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(992): error C2224: left of '.capi' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(992): error C2198: 'F2PyCapsule_Check': too few arguments for call
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(993): error C2065: 'func_cptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(993): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(993): error C2224: left of '.capi' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(993): error C2198: 'F2PyCapsule_AsVoidPtr': too few arguments for call
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(993): warning C4047: '=': 'int' differs in levels of indirection from 'void *'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(995): error C2065: 'func_cptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(995): error C2065: 'func': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(998): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(998): error C2224: left of '.capi' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(998): warning C4133: 'function': incompatible types - from 'PyTupleObject *' to 'PyObject *'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(998): error C2014: preprocessor command must start as first nonwhite space
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1000): error C2059: syntax error: ';'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1001): error C2065: 'func_cb_ptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1001): warning C4013: 'swap_active_func' undefined; assuming extern returning int
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1001): error C2065: 'func_cb_ptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1007): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1007): error C2224: left of '.jmpbuf' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1007): error C2168: '_setjmp': too few actual parameters for intrinsic function
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1010): error C2065: 'func_cptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1010): warning C4022: 'f2py_func': pointer mismatch for actual parameter 1
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1028): error C2065: 'func_cb_ptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1028): error C2065: 'func_cb_ptr': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1029): error C2065: 'func_cb': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1029): error C2224: left of '.args_capi' must have struct/union type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1029): error C2198: '_Py_DECREF': too few arguments for call
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1050): error C2059: syntax error: 'if'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1052): error C2059: syntax error: 'else'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1060): error C2059: syntax error: 'return'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1061): error C2059: syntax error: '}'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1132): error C2065: 'f2py_routine_defs': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1132): error C2109: subscript requires array or pointer type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1133): error C2065: 'f2py_routine_defs': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1133): error C2109: subscript requires array or pointer type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1133): error C2198: 'PyFortranObject_NewAsAttr': too few arguments for call
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1134): error C2065: 'f2py_routine_defs': undeclared identifier
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1134): error C2109: subscript requires array or pointer type
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1134): warning C4133: 'function': incompatible types - from 'PyObject *' to 'const char *'
# C:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c(1134): error C2198: 'PyDict_SetItemString': too few arguments for call
# d:\Anaconda\lib\site-packages\numpy\f2py\f2py2e.py:719: VisibleDeprecationWarning: distutils has been deprecated since NumPy 1.26.xUse the Meson backend instead, or generate wrapperswithout -c and use a custom build script
#   builder = build_backend(
# append_needs: unknown need 'double'
# routsign2map: Confused: function qromb has externals ['func'] but no "use" statement.
# sign2map: Confused: external func is not in lcb_map[].
# append_needs: unknown need 'func'
# append_needs: unknown need 'func'
# d:\Anaconda\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# error: Command "C:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.40.33807\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DNPY_DISABLE_OPTIMIZATION=1 -IC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9 -Id:\Anaconda\lib\site-packages\numpy\core\include -Id:\Anaconda\include -Id:\Anaconda\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Tools\MSVC\14.40.33807\include -IC:\Program Files (x86)\Microsoft Visual Studio\2022\BuildTools\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.22621.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.22621.0\\cppwinrt -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.8\include\um /TcC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.c /FoC:\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\Release\Users\bprav\AppData\Local\Temp\tmp8qnvu50b\src.win-amd64-3.9\rombergmodule.obj" failed with exit status 2

# %%
romberg
