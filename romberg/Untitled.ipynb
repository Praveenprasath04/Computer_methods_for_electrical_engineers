# %%
# script to test the romberg module
from scipy import *
from matplotlib.pyplot import *
import scipy.special as sp
import romberg as r
import numpy as np
# integrate sin(x) as a test
print(r"Testing Trapzd ...")
s=0.0 # initialize the integral to zero
I0=np.cos(0.0)-np.cos(1.0) # the exact value to compare with
print("i\tI[i]\tError")# print a heading
for i in range(1,10):
    s=r.trapzd(lambda x:np.sin(x),0,1,s,i)
    print("%1d %.8f %.2e" % (i,s,s-I0))
# end for
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 5
#       3 from matplotlib.pyplot import *
#       4 import scipy.special as sp
# ----> 5 import romberg as r
#       6 import numpy as np
#       7 # integrate sin(x) as a test
#
# ImportError: DLL load failed while importing romberg: The specified module could not be found.

# %%
# !python -m numpy.f2py -c -m romberg romberg.f
# Out:
# running build
# running config_cc
# INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# INFO: build_src
# INFO: building extension "romberg" sources
# INFO: f2py options: []
# INFO: f2py:> C:\Users\bprav\AppData\Local\Temp\tmpx4y9ud8h\src.win-amd64-3.9\rombergmodule.c
# creating C:\Users\bprav\AppData\Local\Temp\tmpx4y9ud8h\src.win-amd64-3.9
# Reading fortran codes...
# 	Reading file 'romberg.f' (format:fix,strict)
# Post-processing...
# 	Block: romberg
# 			Block: polint
# 			Block: trapzd
# 					Block: func
# 			Block: qromb
# 					Block: func
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Building modules...
#     Constructing call-back function "cb_func_in_trapzd__user__routines"
#       def func(b): return a
# ...
